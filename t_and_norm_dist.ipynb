# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12.0, 8.0)

# %%
x = np.arange(-4.0, 4.0, 0.01)
a = []
n = []
for xi in x:
    a.append(1.0/(1.0+xi*xi))
    n.append(np.exp(-0.5*xi*xi))
plt.plot(x,a,'r', x,n,'g')
plt.show()
